# %%
import pandas as pd

# %%
df = pd.read_csv("athlete_events.csv", dtype = 'str')

# %%
df[(df['NOC']=='IND') & (df['Medal'].notnull())]
# Out:
#             ID                    Name Sex  Age Height Weight   Team  NOC  \
# 4732      2699             Shaukat Ali   M   30    NaN    NaN  India  IND
# 4736      2703        Syed Mushtaq Ali   M   22    165     61  India  IND
# 5032      2864     Richard James Allen   M   25    172    NaN  India  IND
# 5033      2864     Richard James Allen   M   30    172    NaN  India  IND
# 5034      2864     Richard James Allen   M   34    172    NaN  India  IND
# ...        ...                     ...  ..  ...    ...    ...    ...  ...
# 233749  117232      Dung Dung Sylvanus   M   31    160     62  India  IND
# 236445  118553  Carlyle Carrol Tapsell   M   23    182    NaN  India  IND
# 236446  118553  Carlyle Carrol Tapsell   M   27    182    NaN  India  IND
# 250689  125560         Max "Maxie" Vaz   M  NaN    NaN    NaN  India  IND
# 266934  133554    Sayed Muhammad Yusuf   M  NaN    NaN    NaN  India  IND
#
#               Games  Year  Season         City   Sport                Event  \
# ...
